# %%
import torch
from torch import nn
import torchvision as tv
import time
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import GPUtil
GPUtil.showUtilization()
# Out:
# | ID | GPU | MEM |
# ------------------
# |  0 | 24% | 13% |

# %%
import matplotlib.pyplot as plt # plotting
import numpy as np # linear algebra
import os # accessing directory structure
from PIL import Image
from collections import defaultdict
import pandas as pd

# %%
folder_train = "data/tsrd-train"
folder_test = "data/TSRD-Test"
dev = torch.device("cuda") if torch.cuda.is_available() else torch.device("cpu")
dev
# Out:
# device(type='cuda')

# %%
# ищем средний размер картинки
dimensions = defaultdict(int)
count = 0
avg_height = 0
avg_width = 0
for dirname, _, filenames in os.walk(folder_train):
    for filename in filenames:
        #print (dirname, filename)
        image = Image.open(f'{dirname}/{filename}')
        width = image.size[0] 
        height = image.size[1]
        avg_height += height
        avg_width += width
        dimenstion = f'{height}x{width}'
        dimensions[dimenstion] += 1
        count += 1
   
# средний размер картинки
avg_height = avg_height / count
avg_width = avg_width / count
print (f'Avg h = {avg_height}, avg_w = {avg_width}')

# ищем средний размер картинки
dimensions = defaultdict(int)
count = 0
avg_height = 0
avg_width = 0
for dirname, _, filenames in os.walk(folder_test):
    for filename in filenames:
        #print (dirname, filename)
        image = Image.open(f'{dirname}/{filename}')
        width = image.size[0] 
        height = image.size[1]
        avg_height += height
        avg_width += width
        dimenstion = f'{height}x{width}'
        dimensions[dimenstion] += 1
        count += 1
   
# средний размер картинки
avg_height = avg_height / count
avg_width = avg_width / count
print (f'Avg h = {avg_height}, avg_w = {avg_width}')

# проверяем resize
for dirname, _, filenames in os.walk(folder_train):
    for filename in filenames:
        image = Image.open(f'{dirname}/{filename}')
        image = image.resize((110, 110), Image.ANTIALIAS)
        print (image.size)
        break
# Out:
# Avg h = 140.85659472422063, avg_w = 152.13717026378896
# Avg h = 110.09027081243731, avg_w = 115.88164493480441
# (110, 110)

# %%
def my_normalize_tensor(t):
    for i in range(3):
        tmin = t[i].min()
        tmax = t[i].max()
        tsum  = t[i].sum()
        average = tsum/110/110
        #print (tmin, tmax, average)    
        diff = 0.5-average
        t[i] = t[i].add(diff)
    return t

def my_normalize_tensor_1layer(t):
    tmin = t.min()
    tmax = t.max()
    tsum  = t.sum()
    average = tsum/110/110
    diff = 0.5-average
    t = t.add(diff)
    return t

# %%
image = Image.open(f'{folder_train}/002_1_0002.png')
image = image.resize((110, 110), Image.ANTIALIAS)
transform_image = tv.transforms.Compose([ tv.transforms.ToTensor() ])
transform_toimage = tv.transforms.Compose([ tv.transforms.ToPILImage('RGB') ])

image_tensor = transform_image(image)
image_ntensor = my_normalize_tensor(image_tensor)
#image_ntensor = torch.nn.functional.normalize(image_tensor,10)
#image_ntensor = torch.renorm(image_tensor, 2, 2, 0)

image = transform_toimage(image_tensor)
imagen = transform_toimage(image_ntensor)

image
# Out:
# <PIL.Image.Image image mode=RGB size=110x110 at 0xB96E128>

# %%
imagen
# Out:
# <PIL.Image.Image image mode=RGB size=110x110 at 0xB96E080>

# %%
image_tensor[2]
# Out:
# tensor([[0.4694, 0.4733, 0.4733,  ..., 0.4615, 0.4537, 0.4458],
#         [0.4694, 0.4694, 0.4655,  ..., 0.4655, 0.4576, 0.4498],
#         [0.4655, 0.4615, 0.4537,  ..., 0.4772, 0.4733, 0.4615],
#         ...,
#         [0.4733, 0.4733, 0.4733,  ..., 0.5282, 0.4772, 0.4458],
#         [0.4733, 0.4733, 0.4733,  ..., 0.5282, 0.4772, 0.4458],
#         [0.4694, 0.4733, 0.4733,  ..., 0.5321, 0.4811, 0.4419]])

# %%
class CnTrafficSignsDataset(torch.utils.data.Dataset):
    def __init__(self, annotation_file, root_dir, transform=None):
        """
        Args:
            csv_file (string): Path to the csv file with annotations.
            root_dir (string): Directory with all the images.
            transform (callable, optional): Optional transform to be applied
                on a sample.
        """
        self.images = defaultdict(torch.tensor)
        self.root_dir = root_dir
        self.transform = transform  # нафик, тут все сделаю
        
        transform_image = tv.transforms.Compose([
            tv.transforms.Grayscale(1),
            #tv.transforms.ToTensor()
        ])    
        transform_image2 = tv.transforms.Compose([
            #tv.transforms.Grayscale(3),
            tv.transforms.ToTensor()
            
            #tv.transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
        ])
        
        # read all annotated files to memory
        self.annotation = pd.read_csv(annotation_file, sep=';', 
                  names=("fname","a1","a2","a3","a4","a5","a6","class_id","nan"))
        
        for filename in self.annotation["fname"]:
            image = Image.open(f'{root_dir}/{filename}')
            #image = image.resize((110, 110), Image.ANTIALIAS)
            image = image.resize((55, 55), Image.ANTIALIAS)
            image = transform_image(image)
            image_tensor = tv.transforms.functional.adjust_contrast(image,2)
            image_tensor = tv.transforms.functional.adjust_saturation(image,2)
            image_tensor = transform_image2(image)
            image_tensor = my_normalize_tensor_1layer(image_tensor)
            
            image_tensor = image_tensor.to(dev)
            
            self.images[filename] = image_tensor
        
        #self.landmarks_frame = pd.read_csv(csv_file)
        #self.root_dir = root_dir
        #self.transform = transform

    def __len__(self):
        return len(self.images)

    def __getitem__(self, idx):
        if torch.is_tensor(idx):
            idx = idx.tolist()

        image_name = self.annotation.iloc[idx]["fname"]
        image_class = self.annotation.iloc[idx]["class_id"]
        #image_class = torch.tensor(image_class)
        image = self.images[image_name]
        
        sample = [ image, image_class ]
      
        if self.transform:
            sample = self.transform(sample)

        return sample

    def get_fname(self, idx):
        return self.annotation.iloc[idx]["fname"]
    
    def manual_normalize(self, img_min, img_max):
        # detect min and max
        if img_min == 999:
            img_max = -1000
            img_min = 1000
            # detect min and max
            for image in self.images:
                tensor_min = self.images[image].min()
                tensor_max = self.images[image].max()
                if tensor_min < img_min:
                    img_min = tensor_min
                if tensor_max > img_max:
                    img_max = tensor_max
                
        disperse = img_max - img_min
        
        for image in self.images:
            tmp_tensor = self.images[image]
            self.images[image] = (tmp_tensor - img_min) / disperse
            
        return img_min, img_max

# %%
train_dataset = CnTrafficSignsDataset("data/TSRD-Train Annotation/TsignRecgTrain4170Annotation.txt", 
                                      "data/tsrd-train")

# %%
test_dataset = CnTrafficSignsDataset("data/TSRD-Test Annotation/TsignRecgTest1994Annotation.txt", 
                                      "data/TSRD-Test")

# %%
# print (train_dataset[0][0][0])
# img_min, img_max = train_dataset.manual_normalize(999,999)
# print ("----------")
# print (train_dataset[0][0][0])
# print(img_min, img_max)
GPUtil.showUtilization()
# Out:
# | ID | GPU | MEM |
# ------------------
# |  0 |  1% | 20% |

# %%
# смотрим 
def look_at(dataset):
    fig = plt.figure(figsize=(20,20));
    columns = 8;
    rows = 5;
    img_res = [[[0 for x in range(3)] for y in range(110)] for y in range(110)]
    for i in range(1, columns*rows +1):
        #img_xy = np.random.randint(len(train_set));
        img = dataset[i][0].cpu()
        fname = dataset.get_fname(i)
        fig.add_subplot(rows, columns, i)
        plt.title(f'{dataset[i][1]}_{fname}')
        plt.axis('off')
        #plt.imshow(img, cmap='gray')
        img0 = img[0,:,:].numpy()
        img1 = img[1,:,:].numpy()
        img2 = img[2,:,:].numpy()
#         for i in range(110):
#             for j in range(110):
        for i in range(55):
             for j in range(55):
                img_res[i][j][0] = img0[i][j]
                img_res[i][j][1] = img1[i][j]
                img_res[i][j][2] = img2[i][j]
        plt.imshow(img_res)
    plt.show()

# %%
look_at(train_dataset)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-15-6401ae556925> in <module>
# ----> 1 look_at(train_dataset)
#
# <ipython-input-14-1530259f0a6b> in look_at(dataset)
#      14         #plt.imshow(img, cmap='gray')
#      15         img0 = img[0,:,:].numpy()
# ---> 16         img1 = img[1,:,:].numpy()
#      17         img2 = img[2,:,:].numpy()
#      18 #         for i in range(110):
#
# IndexError: index 1 is out of bounds for dimension 0 with size 1

# %%
look_at(test_dataset)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
BATCH_SIZE=100
train_iter = torch.utils.data.DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True)
test_iter = torch.utils.data.DataLoader(test_dataset, batch_size=BATCH_SIZE, shuffle=True)

# %%
GPUtil.showUtilization()
# Out:
# | ID | GPU | MEM |
# ------------------
# |  0 |  1% | 20% |

# %%
# 55x55 test 71%
model = nn.Sequential(
    nn.Conv2d(1, 64, kernel_size=11),
    nn.ReLU(True),
    #nn.BatchNorm2d(80),
    nn.MaxPool2d(2, stride=2),
    nn.Conv2d(64, 128, kernel_size=3),
    nn.ReLU(True),
    
    nn.MaxPool2d(2, stride=2),

#     nn.Conv2d(128, 256, kernel_size=3),
#     nn.ReLU(True),
        
    nn.MaxPool2d(2, stride=2),
#    nn.MaxPool2d(2, stride=2),

    nn.BatchNorm2d(128),
    
    nn.Flatten(),
    #nn.AvgPool2d(3),
    nn.Linear(3200,512),
    nn.ReLU(True),
#     nn.Linear(1000,500),
#     nn.ReLU(True),
    nn.Linear(512, 58),
)

model = model.to(dev)

# %%
X,y = train_dataset[0]
#X = X.reshape(1, 3, 110, 110)
# X = X.reshape(1, 3, 55, 55)
X = X.reshape(1, 1, 55, 55)
for l in model:
    X = l(X)
    print("Layer {}. X shape: {}".format(l, X.shape))
# Out:
# Layer Conv2d(1, 64, kernel_size=(11, 11), stride=(1, 1)). X shape: torch.Size([1, 64, 45, 45])
# Layer ReLU(inplace=True). X shape: torch.Size([1, 64, 45, 45])
# Layer MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False). X shape: torch.Size([1, 64, 22, 22])
# Layer Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1)). X shape: torch.Size([1, 128, 20, 20])
# Layer ReLU(inplace=True). X shape: torch.Size([1, 128, 20, 20])
# Layer MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False). X shape: torch.Size([1, 128, 10, 10])
# Layer MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False). X shape: torch.Size([1, 128, 5, 5])
# Layer BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True). X shape: torch.Size([1, 128, 5, 5])
# Layer Flatten(). X shape: torch.Size([1, 3200])
# Layer Linear(in_features=3200, out_features=512, bias=True). X shape: torch.Size([1, 512])
# Layer ReLU(inplace=True). X shape: torch.Size([1, 512])
# Layer Linear(in_features=512, out_features=58, bias=True). X shape: torch.Size([1, 58])

# %%
def get_accuracy(data_iter, net, dev):
    acc_sum, n = torch.Tensor([0]).to(dev), 0
    for X, y in data_iter:
        X, y = X.to(dev), y.to(dev)
        acc_sum += (net(X).argmax(axis=1) == y).sum()
        n += y.shape[0]
    return acc_sum.item() / n

# %%
def train(net, train_iter, test_iter, trainer, num_epochs, dev):
    loss = nn.CrossEntropyLoss(reduction='sum')
    #loss = nn.CrossEntropyLoss()
    for epoch in range(num_epochs):
        train_l_sum, train_acc_sum, n, start = 0.0, 0.0, 0, time.time()
        for X, y in train_iter:
            trainer.zero_grad()
            y = y.to(dev)
            y_hat = net(X)
            l = loss(y_hat, y)
            l.backward()
            trainer.step()
            train_l_sum += l.item()
            train_acc_sum += (y_hat.argmax(axis=1) == y).sum().item()
            n += y.shape[0]
        test_acc = get_accuracy(test_iter, net, dev)
        #test_acc = 0
        print('epoch %d, loss %.4f, train acc %.3f, test acc %.3f, '
              'time %.1f sec'
              % (epoch + 1, train_l_sum / n, train_acc_sum / n, test_acc,
                 time.time() - start))

# %%
lr, num_epochs = 0.001, 50
#trainer = torch.optim.SGD(model.parameters(), lr=lr)
trainer = torch.optim.Adam(model.parameters(), lr=lr)
train(model, train_iter, test_iter, trainer, num_epochs, dev)
# Out:
# epoch 1, loss 1.2530, train acc 0.714, test acc 0.565, time 3.4 sec
# epoch 2, loss 0.1096, train acc 0.979, test acc 0.686, time 3.3 sec
# epoch 3, loss 0.0223, train acc 0.997, test acc 0.713, time 3.3 sec
# epoch 4, loss 0.0054, train acc 1.000, test acc 0.737, time 3.3 sec
# epoch 5, loss 0.0021, train acc 1.000, test acc 0.741, time 3.3 sec
# epoch 6, loss 0.0011, train acc 1.000, test acc 0.744, time 3.3 sec
# epoch 7, loss 0.0008, train acc 1.000, test acc 0.735, time 3.5 sec
# epoch 8, loss 0.0006, train acc 1.000, test acc 0.741, time 3.3 sec
# epoch 9, loss 0.0005, train acc 1.000, test acc 0.744, time 3.3 sec
# epoch 10, loss 0.0004, train acc 1.000, test acc 0.745, time 3.3 sec
# epoch 11, loss 0.0003, train acc 1.000, test acc 0.750, time 3.3 sec
# epoch 12, loss 0.0003, train acc 1.000, test acc 0.751, time 3.4 sec
# epoch 13, loss 0.0002, train acc 1.000, test acc 0.752, time 3.3 sec
# epoch 14, loss 0.0002, train acc 1.000, test acc 0.758, time 3.3 sec
# epoch 15, loss 0.0002, train acc 1.000, test acc 0.759, time 3.3 sec
# epoch 16, loss 0.0002, train acc 1.000, test acc 0.757, time 3.3 sec
# epoch 17, loss 0.0001, train acc 1.000, test acc 0.759, time 3.3 sec
# epoch 18, loss 0.0001, train acc 1.000, test acc 0.761, time 3.3 sec
# epoch 19, loss 0.0001, train acc 1.000, test acc 0.766, time 3.3 sec
# epoch 20, loss 0.0001, train acc 1.000, test acc 0.759, time 3.3 sec
# epoch 21, loss 0.0001, train acc 1.000, test acc 0.771, time 3.3 sec
# epoch 22, loss 0.0001, train acc 1.000, test acc 0.768, time 3.3 sec
# epoch 23, loss 0.0001, train acc 1.000, test acc 0.765, time 3.3 sec
# epoch 24, loss 0.0001, train acc 1.000, test acc 0.766, time 3.3 sec
# epoch 25, loss 0.0001, train acc 1.000, test acc 0.773, time 3.4 sec
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-39-b3a263ba2661> in <module>
#       2 #trainer = torch.optim.SGD(model.parameters(), lr=lr)
#       3 trainer = torch.optim.Adam(model.parameters(), lr=lr)
# ----> 4 train(model, train_iter, test_iter, trainer, num_epochs, dev)
#
# <ipython-input-38-2c911fe00a9f> in train(net, train_iter, test_iter, trainer, num_epochs, dev)
#       4     for epoch in range(num_epochs):
#       5         train_l_sum, train_acc_sum, n, start = 0.0, 0.0, 0, time.time()
# ----> 6         for X, y in train_iter:
#       7             trainer.zero_grad()
#       8             y = y.to(dev)
#
# C:\ProgramData\Anaconda3\lib\site-packages\torch\utils\data\dataloader.py in __next__(self)
#     344     def __next__(self):
#     345         index = self._next_index()  # may raise StopIteration
# --> 346         data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     347         if self._pin_memory:
#     348             data = _utils.pin_memory.pin_memory(data)
#
# C:\ProgramData\Anaconda3\lib\site-packages\torch\utils\data\_utils\fetch.py in fetch(self, possibly_batched_index)
#      42     def fetch(self, possibly_batched_index):
#      43         if self.auto_collation:
# ---> 44             data = [self.dataset[idx] for idx in possibly_batched_index]
#      45         else:
#      46             data = self.dataset[possibly_batched_index]
#
# C:\ProgramData\Anaconda3\lib\site-packages\torch\utils\data\_utils\fetch.py in <listcomp>(.0)
#      42     def fetch(self, possibly_batched_index):
#      43         if self.auto_collation:
# ---> 44             data = [self.dataset[idx] for idx in possibly_batched_index]
#      45         else:
#      46             data = self.dataset[possibly_batched_index]
#
# <ipython-input-10-0efccef42274> in __getitem__(self, idx)
#      53
#      54         image_name = self.annotation.iloc[idx]["fname"]
# ---> 55         image_class = self.annotation.iloc[idx]["class_id"]
#      56         #image_class = torch.tensor(image_class)
#      57         image = self.images[image_name]
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#    1498
#    1499             maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1500             return self._getitem_axis(maybe_callable, axis=axis)
#    1501
#    1502     def _is_scalar_access(self, key):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    2230             self._validate_integer(key, axis)
#    2231
# -> 2232             return self._get_loc(key, axis=axis)
#    2233
#    2234     def _convert_to_indexer(self, obj, axis=None, is_setter=False):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py in _get_loc(self, key, axis)
#     144         if axis is None:
#     145             axis = self.axis
# --> 146         return self.obj._ixs(key, axis=axis)
#     147
#     148     def _slice(self, obj, axis=None, kind=None):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in _ixs(self, i, axis)
#    2859                                                       index=self.columns,
#    2860                                                       name=self.index[i],
# -> 2861                                                       dtype=new_values.dtype)
#    2862                 result._set_is_copy(self, copy=copy)
#    2863                 return result
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\series.py in __init__(self, data, index, dtype, name, copy, fastpath)
#     262                                       raise_cast_failure=True)
#     263
# --> 264                 data = SingleBlockManager(data, index, fastpath=True)
#     265
#     266         generic.NDFrame.__init__(self, data, fastpath=True)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\internals\managers.py in __init__(self, block, axis, do_integrity_check, fastpath)
#    1479
#    1480         if not isinstance(block, Block):
# -> 1481             block = make_block(block, placement=slice(0, len(axis)), ndim=1)
#    1482
#    1483         self.blocks = [block]
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\internals\blocks.py in make_block(values, placement, klass, ndim, dtype, fastpath)
#    3093         values = DatetimeArray._simple_new(values, dtype=dtype)
#    3094
# -> 3095     return klass(values, ndim=ndim, placement=placement)
#    3096
#    3097
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\internals\blocks.py in __init__(self, values, placement, ndim)
#    2629
#    2630         super(ObjectBlock, self).__init__(values, ndim=ndim,
# -> 2631                                           placement=placement)
#    2632
#    2633     @property
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\internals\blocks.py in __init__(self, values, placement, ndim)
#      78     def __init__(self, values, placement, ndim=None):
#      79         self.ndim = self._check_ndim(values, ndim)
# ---> 80         self.mgr_locs = placement
#      81         self.values = values
#      82
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\internals\blocks.py in mgr_locs(self, new_mgr_locs)
#     199     @mgr_locs.setter
#     200     def mgr_locs(self, new_mgr_locs):
# --> 201         if not isinstance(new_mgr_locs, libinternals.BlockPlacement):
#     202             new_mgr_locs = libinternals.BlockPlacement(new_mgr_locs)
#     203
#
# KeyboardInterrupt:
